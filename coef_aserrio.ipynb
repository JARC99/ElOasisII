# %% [markdown]
# # Coeficiente de Aserrio
# > Dado un vector de diámetros de fuste y dimensiones de las piezas a extraer, se calcula el coeficiente de aserrio para cada caso.

# %%
import numpy as np

# %% [markdown]
# > Debajo se declara en **metros** el vector de diámetros de la siguiente forma: np.arange(**valor inicial, valor final + paso, paso**). Una vez declarado, éste se convierte a pulgadas.

# %%
#DAPs
diametrosarray_m = np.arange(0.36, 0.57, 0.01)
diametrosarray_in = diametrosarray_m / 0.0254

# %% [markdown]
# > Debajo se declara en **pies** el vector de largos de la siguiente forma: np.arange(**valor inicial, valor final + paso, paso**). Una vez declarado, éste se convierte a pulgadas.

# %%
#%% Largos
largoarray_ft = np.arange(7, 14, 1) #Vector de largos (inicio, fin + paso, paso)
largoarray_in = 12*np.arange(7, 14, 1)

# %% [markdown]
# > Debajo se selecciona el herramental de trabajo. Dependiendo de la selección, se habrá de comentar con un **#** al inicio de la línea el otro valor. <br>
# **Ejemplo.** Si se desea usar la Woodmizer como herramient ade trabajo, el código de la celda de abajo deberá ser:<br>
#         #Luz<br>
#         woodmizerluz_mm = 3.429<br>
#         **#**motosierraluz_mm = 9.525<br>
#         luz_in = luz_mm/25.4<br>

# %%
#Luz
woodmizerluz_mm = 3.429 
#motosierraluz_mm = 9.525 
luz_in = luz_mm/25.4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-ad640ac41120> in <module>
#       2 woodmizerluz_mm = 3.429
#       3 #motosierraluz_mm = 9.525
# ----> 4 luz_in = luz_mm/25.4
#
# NameError: name 'luz_mm' is not defined

# %% [markdown]
# > Debajo se declara en **pulgadas** el vector de anchos de tabla siguiente forma: np.arange(**valor inicial, valor final + paso, paso**). Así también se declara el espesor y refuerzos de ésta.

# %%
#%% Tabla
anchotablaarray_in = np.arange(6, 15, 1)
esptabla_in = 1
refuerzoanchotabla_in = 1/4
refuerzoesptabla_in = 1/16

# %% [markdown]
# > Debajo se declara en **pulgadas** el vector de anchos de tablón siguiente forma: np.arange(**valor inicial, valor final + paso, paso**). Así también se declara el espesor y refuerzos de éste.

# %%
#%%Tablón
anchotablonarray_in = np.arange(6, 15, 1)
esptablon_in = 2
refuerzoanchotablon_in = 1/4
refuerzoesptablon_in = 1/4

# %%
#%% No. tablones

for diametro_in in diametrosarray_in:
    no_franjastablon_ = (diametro_in)//(esptablon_in + refuerzoesptablon_in + luz_in)
    
    if (no_franjastablon_ % 2!= 0):
        pasoini_in = (esptablon_in + refuerzoesptablon_in + luz_in)/2
        pasotablonarray_in = np.array([pasoini_in])
    else:
        pasoini_in = 0 
        pasotablonarray_in = np.array([pasoini_in])
    
    for i in range(int(no_franjastablon_//2)):
        pasotablonarray_in = np.append(pasotablonarray_in, (pasoini_in + esptablon_in + refuerzoesptablon_in + luz_in))
        pasoini_in = pasoini_in + esptablon_in + refuerzoesptablon_in + luz_in
        
    anchofranjatablonarray_in = 2*np.sqrt((diametro_in/2)**2 - pasotablonarray_in**2)   
  
#%% No. tablas
    
    sobrantever_in = (diametro_in % (esptablon_in + refuerzoesptablon_in + luz_in))/2
    no_franjastabla_ = (sobrantever_in)//(esptabla_in + refuerzoesptabla_in + luz_in)

    if no_franjastabla_ > 0:
        pasoini_in = pasoini_in + esptabla_in + refuerzoesptabla_in + luz_in
        pasotablaarray_in = np.array([pasoini_in])
        for i in range(int(no_franjastabla_) - 1):
            pasotablaarray_in = np.append(pasotablaarray_in, (pasoini_in + esptabla_in + refuerzoesptabla_in + luz_in))
            pasoini_in = pasoini_in + esptabla_in + refuerzoesptabla_in + luz_in
        
        anchofranjatablaarray_in = 2*np.sqrt((diametro_in/2)**2 - pasotablaarray_in**2)
        print(anchofranjatablaarray_in)
    
    else:
        pasotablaarray_in  = np.array([])
        anchofranjatablaarray_in = np.array([])
    
 #%% Imprsiones
 
    print("Diámetro del tronco = {0:.2f} in = {1:.2f} cm".format(diametro_in, diametro_in*2.54))
    print("No. de franjas de 2 in = {0}".format(no_franjastablon_))
    print("No. de franjas de 1 in = {0}".format(no_franjastabla_))
    
    if (no_franjastablon_ % 2 == 0):
        pasotablonarray_in = np.delete(pasotablonarray_in, 0)   
        anchofranjatablonarraytrunc_in = np.delete(anchofranjatablonarray_in, 0)
        anchofranjatablonarray_in = anchofranjatablonarraytrunc_in 
        print("Coordenada z de cortes: {0}".format(np.concatenate((np.flip(pasotablaarray_in), np.flip(pasotablonarray_in), np.array([0]), -1*pasotablonarray_in, -1*pasotablaarray_in))))
        print("Ancho de franjas: {0}".format(np.concatenate((np.flip(anchofranjatablaarray_in), np.flip(anchofranjatablonarraytrunc_in), anchofranjatablonarraytrunc_in, anchofranjatablaarray_in))))
    else:
        anchofranjatablonmedval_in = anchofranjatablonarray_in[0]
        anchofranjatablonarraytrunc_in = np.delete(anchofranjatablonarray_in, 0)
        print("Coordenada z de cortes: {0}".format(np.concatenate((np.flip(pasotablaarray_in), np.flip(pasotablonarray_in), -1*pasotablonarray_in, -1*pasotablaarray_in))))
        print("Ancho de franjas: {0}".format(np.concatenate((np.flip(anchofranjatablaarray_in), np.flip(anchofranjatablonarraytrunc_in), np.array([anchofranjatablonmedval_in]), anchofranjatablonarraytrunc_in, anchofranjatablaarray_in))))

 #%% Ancho de pieza de 1 in
    areaaprovlist_in2 = []
    if no_franjastabla_ > 0:
        for anchofranjatabla_in in anchofranjatablaarray_in:
            sobrantehor_in = anchofranjatabla_in
            pzaspfranja = {}
            for anchotabla_in in np.flip(anchotablaarray_in):
                pzaspfranja[anchotabla_in] = sobrantehor_in // (anchotabla_in + refuerzoanchotabla_in + luz_in) 
                sobrantehor_in = sobrantehor_in % (anchotabla_in + refuerzoanchotabla_in + + luz_in)
                for ancho, pzapfranja in  pzaspfranja.items():
                    usedarea_in2 = 2*(ancho + refuerzoanchotablon_in)*(esptablon_in + refuerzoesptablon_in)*pzapfranja
                    areaaprovlist_in2.append(usedarea_in2)
        print("Anchos de pieza de 1 in por franja: {0}".format(pzaspfranja))      
    else:
        pass
        
#%% Ancho de pieza de 2 in
    
    for anchofranjatablon_in in np.flip(anchofranjatablonarray_in):
        sobrantehor_in = anchofranjatablon_in
        pzaspfranja = {}
        for anchotablon_in in np.flip(anchotablonarray_in):
            pzaspfranja[anchotablon_in] = sobrantehor_in // (anchotablon_in + refuerzoanchotablon_in + + luz_in) 
            sobrantehor_in = sobrantehor_in % (anchotablon_in + refuerzoanchotablon_in + + luz_in) 
        
        if no_franjastablon_ % 2 == 0: 
            for ancho, pzapfranja in  pzaspfranja.items():
                usedarea_in2 = 2*(ancho)*(esptablon_in)*pzapfranja
                areaaprovlist_in2.append(usedarea_in2)
        else: 
            k = 0
            for ancho, pzapfranja in  pzaspfranja.items():
                if i == 0:
                    usedarea_in2 = (ancho + refuerzoanchotablon_in)*(esptablon_in + refuerzoesptablon_in)*pzapfranja
                else:
                    usedarea_in2 = 2*(ancho)*(esptablon_in)*pzapfranja
                areaaprovlist_in2.append(usedarea_in2)
                k = k + 1
        print("Anchos de pieza de 2 in por franja: {0}".format(pzaspfranja))

#%% Área y volumen aprovechados
        
    areaaprovarray_in2 = np.array(areaaprovlist_in2)
    sumaareaaprov_in2 = np.sum(areaaprovarray_in2)
    areafuste_in2 = (np.pi*diametro_in**2/4)
    porcareaaprov = sumaareaaprov_in2 / areafuste_in2 *100
    volumenaprovarray_FBM = np.around(sumaareaaprov_in2*largoarray_in/144, 2)
    volumenfuste_FBM = np.around(areafuste_in2*largoarray_in/144, 2)
    print("Largos de fuste = {0}".format(largoarray_ft))
    print("Volumenes de fuste = {0} FBM".format(volumenfuste_FBM))
    print("Volumen extraido = {0} FBM".format(volumenaprovarray_FBM))
    print("Porcentaje de área aprovechada = {0:.2f} %".format(porcareaaprov))
    print("\n")
# Out:
# Diámetro del tronco = 14.17 in = 36.00 cm
# No. de franjas de 2 in = 5.0
# No. de franjas de 1 in = 0.0
# Coordenada z de cortes: [ 6.5625  3.9375  1.3125 -1.3125 -3.9375 -6.5625]
# Ancho de franjas: [ 5.34927815 11.78408998 13.92802128 11.78408998  5.34927815]
# Anchos de pieza de 2 in por franja: {14: 0.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 0.0, 13: 0.0, 12: 0.0, 11: 1.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 0.0, 13: 1.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Largos de fuste = [ 7  8  9 10 11 12 13]
# Volumenes de fuste = [ 92.03 105.18 118.33 131.48 144.62 157.77 170.92] FBM
# Volumen extraido = [ 56.  64.  72.  80.  88.  96. 104.] FBM
# Porcentaje de área aprovechada = 60.85 %
#
#
# Diámetro del tronco = 14.57 in = 37.00 cm
# No. de franjas de 2 in = 5.0
# No. de franjas de 1 in = 0.0
# Coordenada z de cortes: [ 6.5625  3.9375  1.3125 -1.3125 -3.9375 -6.5625]
# Ancho de franjas: [ 6.31900304 12.25478679 14.32846117 12.25478679  6.31900304]
# Anchos de pieza de 2 in por franja: {14: 0.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 0.0, 13: 0.0, 12: 0.0, 11: 1.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 0.0, 13: 1.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Largos de fuste = [ 7  8  9 10 11 12 13]
# Volumenes de fuste = [ 97.22 111.11 124.99 138.88 152.77 166.66 180.55] FBM
# Volumen extraido = [ 56.  64.  72.  80.  88.  96. 104.] FBM
# Porcentaje de área aprovechada = 57.60 %
#
#
# Diámetro del tronco = 14.96 in = 38.00 cm
# No. de franjas de 2 in = 5.0
# No. de franjas de 1 in = 0.0
# Coordenada z de cortes: [ 6.5625  3.9375  1.3125 -1.3125 -3.9375 -6.5625]
# Ancho de franjas: [ 7.18016871 12.72025246 14.7285377  12.72025246  7.18016871]
# Anchos de pieza de 2 in por franja: {14: 0.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 1.0}
# Anchos de pieza de 2 in por franja: {14: 0.0, 13: 0.0, 12: 1.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 1.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Largos de fuste = [ 7  8  9 10 11 12 13]
# Volumenes de fuste = [102.54 117.19 131.84 146.49 161.14 175.79 190.44] FBM
# Volumen extraido = [ 74.67  85.33  96.   106.67 117.33 128.   138.67] FBM
# Porcentaje de área aprovechada = 72.81 %
#
#
# Diámetro del tronco = 15.35 in = 39.00 cm
# No. de franjas de 2 in = 5.0
# No. de franjas de 1 in = 0.0
# Coordenada z de cortes: [ 6.5625  3.9375  1.3125 -1.3125 -3.9375 -6.5625]
# Ancho de franjas: [ 7.96805161 13.18104118 15.12827969 13.18104118  7.96805161]
# Anchos de pieza de 2 in por franja: {14: 0.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 1.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 0.0, 13: 0.0, 12: 1.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 1.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Largos de fuste = [ 7  8  9 10 11 12 13]
# Volumenes de fuste = [108.01 123.44 138.87 154.3  169.73 185.16 200.59] FBM
# Volumen extraido = [ 77.  88.  99. 110. 121. 132. 143.] FBM
# Porcentaje de área aprovechada = 71.29 %
#
#
# Diámetro del tronco = 15.75 in = 40.00 cm
# No. de franjas de 2 in = 5.0
# No. de franjas de 1 in = 0.0
# Coordenada z de cortes: [ 6.5625  3.9375  1.3125 -1.3125 -3.9375 -6.5625]
# Ancho de franjas: [ 8.70257841 13.63762703 15.527713   13.63762703  8.70257841]
# Anchos de pieza de 2 in por franja: {14: 0.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 1.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 0.0, 13: 1.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 1.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Largos de fuste = [ 7  8  9 10 11 12 13]
# Volumenes de fuste = [113.62 129.85 146.08 162.32 178.55 194.78 211.01] FBM
# Volumen extraido = [ 81.67  93.33 105.   116.67 128.33 140.   151.67] FBM
# Porcentaje de área aprovechada = 71.88 %
#
#
# Diámetro del tronco = 16.14 in = 41.00 cm
# No. de franjas de 2 in = 6.0
# No. de franjas de 1 in = 0.0
# Coordenada z de cortes: [ 7.875  5.25   2.625  0.    -2.625 -5.25  -7.875]
# Ancho de franjas: [ 3.5345468  12.25991522 15.26410892 15.26410892 12.25991522  3.5345468 ]
# Anchos de pieza de 2 in por franja: {14: 0.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 0.0, 13: 0.0, 12: 0.0, 11: 1.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 1.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Largos de fuste = [ 7  8  9 10 11 12 13]
# Volumenes de fuste = [119.37 136.43 153.48 170.53 187.59 204.64 221.69] FBM
# Volumen extraido = [ 58.33  66.67  75.    83.33  91.67 100.   108.33] FBM
# Porcentaje de área aprovechada = 48.87 %
#
#
# Diámetro del tronco = 16.54 in = 42.00 cm
# No. de franjas de 2 in = 6.0
# No. de franjas de 1 in = 0.0
# Coordenada z de cortes: [ 7.875  5.25   2.625  0.    -2.625 -5.25  -7.875]
# Ancho de franjas: [ 5.0356774  12.77382272 15.67986119 15.67986119 12.77382272  5.0356774 ]
# Anchos de pieza de 2 in por franja: {14: 0.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 0.0, 13: 0.0, 12: 1.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 1.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Largos de fuste = [ 7  8  9 10 11 12 13]
# Volumenes de fuste = [125.27 143.16 161.06 178.95 196.85 214.74 232.64] FBM
# Volumen extraido = [ 60.67  69.33  78.    86.67  95.33 104.   112.67] FBM
# Porcentaje de área aprovechada = 48.43 %
#
#
# Diámetro del tronco = 16.93 in = 43.00 cm
# No. de franjas de 2 in = 6.0
# No. de franjas de 1 in = 0.0
# Coordenada z de cortes: [ 7.875  5.25   2.625  0.    -2.625 -5.25  -7.875]
# Ancho de franjas: [ 6.20750136 13.27951705 16.09450444 16.09450444 13.27951705  6.20750136]
# Anchos de pieza de 2 in por franja: {14: 0.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 0.0, 13: 0.0, 12: 1.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 1.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Largos de fuste = [ 7  8  9 10 11 12 13]
# Volumenes de fuste = [131.3  150.06 168.82 187.58 206.33 225.09 243.85] FBM
# Volumen extraido = [ 60.67  69.33  78.    86.67  95.33 104.   112.67] FBM
# Porcentaje de área aprovechada = 46.20 %
#
#
# Diámetro del tronco = 17.32 in = 44.00 cm
# No. de franjas de 2 in = 6.0
# No. de franjas de 1 in = 0.0
# Coordenada z de cortes: [ 7.875  5.25   2.625  0.    -2.625 -5.25  -7.875]
# Ancho de franjas: [ 7.21235746 13.7779026  16.50812225 16.50812225 13.7779026   7.21235746]
# Anchos de pieza de 2 in por franja: {14: 0.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 1.0}
# Anchos de pieza de 2 in por franja: {14: 0.0, 13: 1.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 1.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Largos de fuste = [ 7  8  9 10 11 12 13]
# Volumenes de fuste = [137.48 157.12 176.76 196.4  216.04 235.68 255.32] FBM
# Volumen extraido = [ 77.  88.  99. 110. 121. 132. 143.] FBM
# Porcentaje de área aprovechada = 56.01 %
#
#
# Diámetro del tronco = 17.72 in = 45.00 cm
# No. de franjas de 2 in = 6.0
# No. de franjas de 1 in = 0.0
# Coordenada z de cortes: [ 7.875  5.25   2.625  0.    -2.625 -5.25  -7.875]
# Ancho de franjas: [ 8.11252906 14.26974519 16.92078981 16.92078981 14.26974519  8.11252906]
# Anchos de pieza de 2 in por franja: {14: 0.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 1.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 0.0, 13: 1.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 1.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Largos de fuste = [ 7  8  9 10 11 12 13]
# Volumenes de fuste = [143.8  164.34 184.89 205.43 225.97 246.52 267.06] FBM
# Volumen extraido = [ 79.33  90.67 102.   113.33 124.67 136.   147.33] FBM
# Porcentaje de área aprovechada = 55.17 %
#
#
# Diámetro del tronco = 18.11 in = 46.00 cm
# No. de franjas de 2 in = 6.0
# No. de franjas de 1 in = 0.0
# Coordenada z de cortes: [ 7.875  5.25   2.625  0.    -2.625 -5.25  -7.875]
# Ancho de franjas: [ 8.93969552 14.7556991  17.332575   17.332575   14.7556991   8.93969552]
# Anchos de pieza de 2 in por franja: {14: 0.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 1.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 1.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 1.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Largos de fuste = [ 7  8  9 10 11 12 13]
# Volumenes de fuste = [150.26 171.73 193.2  214.66 236.13 257.6  279.06] FBM
# Volumen extraido = [ 84.  96. 108. 120. 132. 144. 156.] FBM
# Porcentaje de área aprovechada = 55.90 %
#
#
# Diámetro del tronco = 18.50 in = 47.00 cm
# No. de franjas de 2 in = 7.0
# No. de franjas de 1 in = 0.0
# Coordenada z de cortes: [ 9.1875  6.5625  3.9375  1.3125 -1.3125 -3.9375 -6.5625 -9.1875]
# Ancho de franjas: [ 2.18060996 13.04339142 16.74455314 18.3167972  16.74455314 13.04339142
#   2.18060996]
# Anchos de pieza de 2 in por franja: {14: 0.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 0.0, 13: 0.0, 12: 1.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 1.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 1.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Largos de fuste = [ 7  8  9 10 11 12 13]
# Volumenes de fuste = [156.87 179.28 201.69 224.1  246.51 268.92 291.33] FBM
# Volumen extraido = [ 93.33 106.67 120.   133.33 146.67 160.   173.33] FBM
# Porcentaje de área aprovechada = 59.50 %
#
#
# Diámetro del tronco = 18.90 in = 48.00 cm
# No. de franjas de 2 in = 7.0
# No. de franjas de 1 in = 0.0
# Coordenada z de cortes: [ 9.1875  6.5625  3.9375  1.3125 -1.3125 -3.9375 -6.5625 -9.1875]
# Ancho de franjas: [ 4.41362541 13.59614244 17.17862303 18.71443532 17.17862303 13.59614244
#   4.41362541]
# Anchos de pieza de 2 in por franja: {14: 0.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 0.0, 13: 0.0, 12: 1.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 1.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 1.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Largos de fuste = [ 7  8  9 10 11 12 13]
# Volumenes de fuste = [163.61 186.99 210.36 233.73 257.11 280.48 303.86] FBM
# Volumen extraido = [ 93.33 106.67 120.   133.33 146.67 160.   173.33] FBM
# Porcentaje de área aprovechada = 57.04 %
#
#
# Diámetro del tronco = 19.29 in = 49.00 cm
# No. de franjas de 2 in = 7.0
# No. de franjas de 1 in = 0.0
# Coordenada z de cortes: [ 9.1875  6.5625  3.9375  1.3125 -1.3125 -3.9375 -6.5625 -9.1875]
# Ancho de franjas: [ 5.87495696 14.13825022 17.61079553 19.1119104  17.61079553 14.13825022
#   5.87495696]
# Anchos de pieza de 2 in por franja: {14: 0.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 0.0, 13: 1.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 1.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 1.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Largos de fuste = [ 7  8  9 10 11 12 13]
# Volumenes de fuste = [170.5  194.86 219.22 243.58 267.93 292.29 316.65] FBM
# Volumen extraido = [ 95.67 109.33 123.   136.67 150.33 164.   177.67] FBM
# Porcentaje de área aprovechada = 56.11 %
#
#
# Diámetro del tronco = 19.69 in = 50.00 cm
# No. de franjas de 2 in = 7.0
# No. de franjas de 1 in = 0.0
# Coordenada z de cortes: [ 9.1875  6.5625  3.9375  1.3125 -1.3125 -3.9375 -6.5625 -9.1875]
# Ancho de franjas: [ 7.061172   14.67089466 18.041207   19.50923243 18.041207   14.67089466
#   7.061172  ]
# Anchos de pieza de 2 in por franja: {14: 0.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 1.0}
# Anchos de pieza de 2 in por franja: {14: 1.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 1.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 1.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Largos de fuste = [ 7  8  9 10 11 12 13]
# Volumenes de fuste = [177.53 202.89 228.26 253.62 278.98 304.34 329.7 ] FBM
# Volumen extraido = [112. 128. 144. 160. 176. 192. 208.] FBM
# Porcentaje de área aprovechada = 63.09 %
#
#
# Diámetro del tronco = 20.08 in = 51.00 cm
# No. de franjas de 2 in = 7.0
# No. de franjas de 1 in = 0.0
# Coordenada z de cortes: [ 9.1875  6.5625  3.9375  1.3125 -1.3125 -3.9375 -6.5625 -9.1875]
# Ancho de franjas: [ 8.09414488 15.19507095 18.46998054 19.90641056 18.46998054 15.19507095
#   8.09414488]
# Anchos de pieza de 2 in por franja: {14: 0.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 1.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 1.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 1.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 1.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Largos de fuste = [ 7  8  9 10 11 12 13]
# Volumenes de fuste = [184.71 211.09 237.48 263.86 290.25 316.64 343.02] FBM
# Volumen extraido = [114.33 130.67 147.   163.33 179.67 196.   212.33] FBM
# Porcentaje de área aprovechada = 61.90 %
#
#
# Diámetro del tronco = 20.47 in = 52.00 cm
# No. de franjas de 2 in = 7.0
# No. de franjas de 1 in = 0.0
# Coordenada z de cortes: [ 9.1875  6.5625  3.9375  1.3125 -1.3125 -3.9375 -6.5625 -9.1875]
# Ancho de franjas: [ 9.02663909 15.71162669 18.89722766 20.30345323 18.89722766 15.71162669
#   9.02663909]
# Anchos de pieza de 2 in por franja: {14: 0.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 1.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 1.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 1.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 1.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Largos de fuste = [ 7  8  9 10 11 12 13]
# Volumenes de fuste = [192.02 219.45 246.88 274.31 301.75 329.18 356.61] FBM
# Volumen extraido = [116.67 133.33 150.   166.67 183.33 200.   216.67] FBM
# Porcentaje de área aprovechada = 60.76 %
#
#
# Diámetro del tronco = 20.87 in = 53.00 cm
# No. de franjas de 2 in = 7.0
# No. de franjas de 1 in = 0.0
# Coordenada z de cortes: [ 9.1875  6.5625  3.9375  1.3125 -1.3125 -3.9375 -6.5625 -9.1875]
# Ancho de franjas: [ 9.88712525 16.22128989 19.3230496  20.70036825 19.3230496  16.22128989
#   9.88712525]
# Anchos de pieza de 2 in por franja: {14: 0.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 1.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 1.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 1.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 1.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Largos de fuste = [ 7  8  9 10 11 12 13]
# Volumenes de fuste = [199.48 227.97 256.47 284.97 313.46 341.96 370.46] FBM
# Volumen extraido = [119. 136. 153. 170. 187. 204. 221.] FBM
# Porcentaje de área aprovechada = 59.66 %
#
#
# Diámetro del tronco = 21.26 in = 54.00 cm
# No. de franjas de 2 in = 8.0
# No. de franjas de 1 in = 0.0
# Coordenada z de cortes: [ 10.5     7.875   5.25    2.625   0.     -2.625  -5.25   -7.875 -10.5  ]
# Ancho de franjas: [ 3.3137447  14.28000014 18.48596505 20.60141752 20.60141752 18.48596505
#  14.28000014  3.3137447 ]
# Anchos de pieza de 2 in por franja: {14: 0.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 0.0, 13: 1.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 1.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 1.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Largos de fuste = [ 7  8  9 10 11 12 13]
# Volumenes de fuste = [207.07 236.66 266.24 295.82 325.4  354.98 384.57] FBM
# Volumen extraido = [ 95.67 109.33 123.   136.67 150.33 164.   177.67] FBM
# Porcentaje de área aprovechada = 46.20 %
#
#
# Diámetro del tronco = 21.65 in = 55.00 cm
# No. de franjas de 2 in = 8.0
# No. de franjas de 1 in = 0.0
# Coordenada z de cortes: [ 10.5     7.875   5.25    2.625   0.     -2.625  -5.25   -7.875 -10.5  ]
# Ancho de franjas: [ 5.27976683 14.85979266 18.93742162 21.00746148 21.00746148 18.93742162
#  14.85979266  5.27976683]
# Anchos de pieza de 2 in por franja: {14: 0.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 1.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 1.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 1.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Largos de fuste = [ 7  8  9 10 11 12 13]
# Volumenes de fuste = [214.82 245.5  276.19 306.88 337.57 368.25 398.94] FBM
# Volumen extraido = [ 98. 112. 126. 140. 154. 168. 182.] FBM
# Porcentaje de área aprovechada = 45.62 %
#
#
# Diámetro del tronco = 22.05 in = 56.00 cm
# No. de franjas de 2 in = 8.0
# No. de franjas de 1 in = 0.0
# Coordenada z de cortes: [ 10.5     7.875   5.25    2.625   0.     -2.625  -5.25   -7.875 -10.5  ]
# Ancho de franjas: [ 6.71423653 15.4278473  19.38636047 21.41304444 21.41304444 19.38636047
#  15.4278473   6.71423653]
# Anchos de pieza de 2 in por franja: {14: 0.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 1.0}
# Anchos de pieza de 2 in por franja: {14: 1.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 1.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 0.0}
# Anchos de pieza de 2 in por franja: {14: 1.0, 13: 0.0, 12: 0.0, 11: 0.0, 10: 0.0, 9: 0.0, 8: 0.0, 7: 0.0, 6: 1.0}
# Largos de fuste = [ 7  8  9 10 11 12 13]
# Volumenes de fuste = [222.7  254.51 286.33 318.14 349.95 381.77 413.58] FBM
# Volumen extraido = [126. 144. 162. 180. 198. 216. 234.] FBM
# Porcentaje de área aprovechada = 56.58 %
